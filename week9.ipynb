# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-approval-prediction/credit_record.csv
# /kaggle/input/credit-card-approval-prediction/application_record.csv

# %%
df = pd.read_csv('../input/credit-card-approval-prediction/application_record.csv',header=0)
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 438552              1.0
# 438553              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0
#
# [438557 rows x 18 columns]

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# 25%     -3103.000000         1.0         0.000000       0.000000
# 50%     -1467.000000         1.0         0.000000       0.000000
# 75%      -371.000000         1.0         0.000000       1.000000
# max    365243.000000         1.0         1.000000       1.000000
#
#           FLAG_EMAIL  CNT_FAM_MEMBERS
# count  438557.000000    438557.000000
# mean        0.108207         2.194465
# std         0.310642         0.897207
# min         0.000000         1.000000
# 25%         0.000000         2.000000
# 50%         0.000000         2.000000
# 75%         0.000000         3.000000
# max         1.000000        20.000000

# %%
df.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE         True
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df.groupby('NAME_HOUSING_TYPE')['NAME_HOUSING_TYPE'].count()
# Out:
# NAME_HOUSING_TYPE
# Co-op apartment          1539
# House / apartment      393831
# Municipal apartment     14214
# Office apartment         3922
# Rented apartment         5974
# With parents            19077
# Name: NAME_HOUSING_TYPE, dtype: int64

# %%
df.groupby('NAME_FAMILY_STATUS')['NAME_FAMILY_STATUS'].count()
# Out:
# NAME_FAMILY_STATUS
# Civil marriage           36532
# Married                 299828
# Separated                27251
# Single / not married     55271
# Widow                    19675
# Name: NAME_FAMILY_STATUS, dtype: int64

# %%
df.groupby('OCCUPATION_TYPE')['OCCUPATION_TYPE'].count()
# Out:
# OCCUPATION_TYPE
# Accountants              15985
# Cleaning staff            5845
# Cooking staff             8076
# Core staff               43007
# Drivers                  26090
# HR staff                   774
# High skill tech staff    17289
# IT staff                   604
# Laborers                 78240
# Low-skill Laborers        2140
# Managers                 35487
# Medicine staff           13520
# Private service staff     3456
# Realty agents             1041
# Sales staff              41098
# Secretaries               2044
# Security staff            7993
# Waiters/barmen staff      1665
# Name: OCCUPATION_TYPE, dtype: int64

# %%
df_clean = df.dropna(axis = 0)
df_clean.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df_clean_drop = df_clean.drop(['DAYS_BIRTH','FLAG_EMAIL','FLAG_WORK_PHONE','FLAG_PHONE','FLAG_MOBIL','CODE_GENDER'], axis=1)

# %%
df_clean_drop.isnull().any()
# Out:
# ID                     False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_EMPLOYED          False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df_clean_drop
# Out:
#              ID FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 2       5008806            Y               Y             0          112500.0
# 3       5008808            N               Y             0          270000.0
# 4       5008809            N               Y             0          270000.0
# 5       5008810            N               Y             0          270000.0
# 6       5008811            N               Y             0          270000.0
# ...         ...          ...             ...           ...               ...
# 438541  6837707            N               Y             0          202500.0
# 438548  6839936            Y               Y             1          135000.0
# 438553  6840222            N               N             0          103500.0
# 438554  6841878            N               N             0           54000.0
# 438556  6842885            N               Y             0          121500.0
#
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 2                    Working  Secondary / secondary special
# 3       Commercial associate  Secondary / secondary special
# 4       Commercial associate  Secondary / secondary special
# 5       Commercial associate  Secondary / secondary special
# 6       Commercial associate  Secondary / secondary special
# ...                      ...                            ...
# 438541               Working               Higher education
# 438548               Working  Secondary / secondary special
# 438553               Working  Secondary / secondary special
# 438554  Commercial associate               Higher education
# 438556               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_EMPLOYED  \
# 2                    Married  House / apartment          -1134
# 3       Single / not married  House / apartment          -3051
# 4       Single / not married  House / apartment          -3051
# 5       Single / not married  House / apartment          -3051
# 6       Single / not married  House / apartment          -3051
# ...                      ...                ...            ...
# 438541        Civil marriage  House / apartment          -2309
# 438548               Married  House / apartment          -2095
# 438553  Single / not married  House / apartment          -3007
# 438554  Single / not married       With parents           -372
# 438556               Married  House / apartment          -1201
#
#        OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 2       Security staff              2.0
# 3          Sales staff              1.0
# 4          Sales staff              1.0
# 5          Sales staff              1.0
# 6          Sales staff              1.0
# ...                ...              ...
# 438541        Laborers              2.0
# 438548        Laborers              3.0
# 438553        Laborers              1.0
# 438554     Sales staff              1.0
# 438556     Sales staff              2.0
#
# [304354 rows x 12 columns]

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df_clean_drop['FLAG_OWN_CAR'] = pd.factorize(df_clean_drop['FLAG_OWN_CAR'])[0]
df_clean_drop['FLAG_OWN_REALTY'] = pd.factorize(df_clean_drop['FLAG_OWN_REALTY'])[0]
df_clean_drop['NAME_INCOME_TYPE'] = pd.factorize(df_clean_drop['NAME_INCOME_TYPE'])[0]
df_clean_drop['NAME_EDUCATION_TYPE'] = pd.factorize(df_clean_drop['NAME_EDUCATION_TYPE'])[0]
df_clean_drop['NAME_FAMILY_STATUS'] = pd.factorize(df_clean_drop['NAME_FAMILY_STATUS'])[0]
df_clean_drop['NAME_HOUSING_TYPE'] = pd.factorize(df_clean_drop['NAME_HOUSING_TYPE'])[0]
df_clean_drop['OCCUPATION_TYPE'] = pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR             int64
# FLAG_OWN_REALTY          int64
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE         int64
# NAME_EDUCATION_TYPE      int64
# NAME_FAMILY_STATUS       int64
# NAME_HOUSING_TYPE        int64
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE          int64
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df_clean_drop
# Out:
#              ID  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 2       5008806             0                0             0
# 3       5008808             1                0             0
# 4       5008809             1                0             0
# 5       5008810             1                0             0
# 6       5008811             1                0             0
# ...         ...           ...              ...           ...
# 438541  6837707             1                0             0
# 438548  6839936             0                0             1
# 438553  6840222             1                1             0
# 438554  6841878             1                1             0
# 438556  6842885             1                0             0
#
#         AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 2               112500.0                 0                    0
# 3               270000.0                 1                    0
# 4               270000.0                 1                    0
# 5               270000.0                 1                    0
# 6               270000.0                 1                    0
# ...                  ...               ...                  ...
# 438541          202500.0                 0                    1
# 438548          135000.0                 0                    0
# 438553          103500.0                 0                    0
# 438554           54000.0                 1                    1
# 438556          121500.0                 0                    0
#
#         NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_EMPLOYED  OCCUPATION_TYPE  \
# 2                        0                  0          -1134                0
# 3                        1                  0          -3051                1
# 4                        1                  0          -3051                1
# 5                        1                  0          -3051                1
# 6                        1                  0          -3051                1
# ...                    ...                ...            ...              ...
# 438541                   2                  0          -2309                3
# 438548                   0                  0          -2095                3
# 438553                   1                  0          -3007                3
# 438554                   1                  3           -372                1
# 438556                   0                  0          -1201                1
#
#         CNT_FAM_MEMBERS
# 2                   2.0
# 3                   1.0
# 4                   1.0
# 5                   1.0
# 6                   1.0
# ...                 ...
# 438541              2.0
# 438548              3.0
# 438553              1.0
# 438554              1.0
# 438556              2.0
#
# [304354 rows x 12 columns]

# %%
X = df_clean_drop.values 
X.shape
# Out:
# (304354, 12)

# %%
df_label = pd.read_csv('../input/credit-card-approval-prediction/credit_record.csv',header=0)
df_label
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
df_label.groupby('ID')['STATUS'].count()
# Out:
# ID
# 5001711     4
# 5001712    19
# 5001713    22
# 5001714    15
# 5001715    60
#            ..
# 5150482    18
# 5150483    18
# 5150484    13
# 5150485     2
# 5150487    30
# Name: STATUS, Length: 45985, dtype: int64

# %%
df_label['STATUS'], labels = pd.factorize(df_label['STATUS'])

# %%
labels
# Out:
# Index(['X', '0', 'C', '1', '2', '3', '4', '5'], dtype='object')

# %%
df_label['STATUS'] != 0
# Out:
# 0          False
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1048570     True
# 1048571     True
# 1048572     True
# 1048573     True
# 1048574     True
# Name: STATUS, Length: 1048575, dtype: bool

# %%
df_label_clean = df_label[df_label['STATUS'] != 0]

# %%
df_label_clean
# Out:
#               ID  MONTHS_BALANCE  STATUS
# 1        5001711              -1       1
# 2        5001711              -2       1
# 3        5001711              -3       1
# 4        5001712               0       2
# 5        5001712              -1       2
# ...          ...             ...     ...
# 1048570  5150487             -25       2
# 1048571  5150487             -26       2
# 1048572  5150487             -27       2
# 1048573  5150487             -28       2
# 1048574  5150487             -29       2
#
# [839345 rows x 3 columns]

# %%
df_label_clean['STATUS'][df_label['STATUS'] > 2] = 10
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_clean['STATUS'][df_label['STATUS'] <= 2] = 0
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_clean.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0     825151
# 10     14194
# Name: STATUS, dtype: int64

# %%
df_label_clean.groupby('ID').mean()
# Out:
#          MONTHS_BALANCE    STATUS
# ID
# 5001711       -2.000000  0.000000
# 5001712       -9.000000  0.000000
# 5001717      -10.500000  0.000000
# 5001718      -18.724138  0.689655
# 5001719      -21.000000  0.000000
# ...                 ...       ...
# 5150480      -36.500000  0.000000
# 5150482      -19.500000  0.000000
# 5150484       -6.000000  0.000000
# 5150485       -0.500000  0.000000
# 5150487      -14.500000  0.000000
#
# [41449 rows x 2 columns]

# %%
df_label_group = df_label_clean.groupby('ID').mean()

# %%
df_label_group['STATUS'][df_label_group['STATUS'] > 0] = 1
df_label_group['STATUS'][df_label_group['STATUS'] <= 0] = 0

# %%
df_label_group
# Out:
#          MONTHS_BALANCE  STATUS
# ID
# 5001711       -2.000000     0.0
# 5001712       -9.000000     0.0
# 5001717      -10.500000     0.0
# 5001718      -18.724138     1.0
# 5001719      -21.000000     0.0
# ...                 ...     ...
# 5150480      -36.500000     0.0
# 5150482      -19.500000     0.0
# 5150484       -6.000000     0.0
# 5150485       -0.500000     0.0
# 5150487      -14.500000     0.0
#
# [41449 rows x 2 columns]

# %%
df_label_group.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0.0    36099
# 1.0     5350
# Name: STATUS, dtype: int64

# %%
client_id = df_label_group.index.values
client_label = df_label_group['STATUS'].values

# %%
X_clien_id = df_clean_drop['ID'].values
df_clean_drop = df_clean_drop.drop(['ID'], axis = 1)

# %%
X = df_clean_drop.values
X.shape
# Out:
# (304354, 11)

# %%
real_client_id = np.array([item for item in X_clien_id if item in client_id])

# %%
y = np.array([client_label[client_id == item][0] for item in real_client_id])

# %%
X_final = [X[X_clien_id == item, :][0] for item in real_client_id]

# %%
X_real_final = np.vstack(X_final)

# %%
X_real_final.shape
# Out:
# (22737, 11)

# %%
len(y)
# Out:
# 22737

# %%
sum(y==0)
# Out:
# 19648

# %%
sum(y==1)
# Out:
# 3089

# %%
from imblearn.under_sampling import RandomUnderSampler
sm = RandomUnderSampler(random_state=1)
X_res, y_res = sm.fit_resample(X_real_final, y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X_train)
X_train_norm =  scaler.transform(X_train)
X_val_norm = scaler.transform(X_val)
X_test_norm = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

params = {'C': [1, 2, 4, 8, 16]}
clf = GridSearchCV(LogisticRegression(random_state=0, solver='liblinear'),params, cv=10)
clf.fit(X_train_norm, y_train)
print("Best params : " + str(clf.best_params_))
print("10CV accuracy : "+str(clf.best_score_*100))
# Out:
# Best params : {'C': 4}
# 10CV accuracy : 53.40269786472318

# %%
y_predict = clf.predict(X_test_norm)
print("Test accuracy : "+str(sum(y_test == y_predict)/len(y_test)*100))
# Out:
# Test accuracy : 52.02265372168284

# %%
import tensorflow as tf

# %%
tf.compat.v1.reset_default_graph() 
np.random.seed(1) 
tf.compat.v1.random.set_random_seed(1) 
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(250, activation='relu', input_shape=(11,)),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dense(150, activation='relu'),
  tf.keras.layers.Dense(100, activation='relu'),
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')    
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 250)               3000
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               50200
# _________________________________________________________________
# dense_2 (Dense)              (None, 150)               30150
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               15100
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 103,551
# Trainable params: 103,551
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
train_acc = list()
val_acc = list()
for i in range(0,250):
  history = model.fit(X_train_norm, y_train, epochs= 1, batch_size = 200, validation_data= (X_val_norm, y_val))
  tmp_avg = np.mean(history.history['accuracy'])
  tmp_avg_val = np.mean(history.history['val_accuracy'])
  train_acc.append(tmp_avg)
  val_acc.append(tmp_avg_val)
# Out:
# 20/20 [==============================] - 1s 39ms/step - loss: 0.6927 - accuracy: 0.5133 - val_loss: 0.6940 - val_accuracy: 0.5167
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6896 - accuracy: 0.5360 - val_loss: 0.6964 - val_accuracy: 0.5268
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6891 - accuracy: 0.5391 - val_loss: 0.6952 - val_accuracy: 0.5268
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6875 - accuracy: 0.5426 - val_loss: 0.6952 - val_accuracy: 0.5258
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6861 - accuracy: 0.5444 - val_loss: 0.6949 - val_accuracy: 0.5359
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6836 - accuracy: 0.5507 - val_loss: 0.6942 - val_accuracy: 0.5399
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6803 - accuracy: 0.5573 - val_loss: 0.6944 - val_accuracy: 0.5369
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6756 - accuracy: 0.5644 - val_loss: 0.6962 - val_accuracy: 0.5460
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6716 - accuracy: 0.5755 - val_loss: 0.6968 - val_accuracy: 0.5561
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6672 - accuracy: 0.5846 - val_loss: 0.6960 - val_accuracy: 0.5511
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6628 - accuracy: 0.5899 - val_loss: 0.6978 - val_accuracy: 0.5258
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6582 - accuracy: 0.5932 - val_loss: 0.7019 - val_accuracy: 0.5248
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6538 - accuracy: 0.5963 - val_loss: 0.7047 - val_accuracy: 0.5258
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6507 - accuracy: 0.6054 - val_loss: 0.7104 - val_accuracy: 0.5460
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6470 - accuracy: 0.6089 - val_loss: 0.7090 - val_accuracy: 0.5460
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6443 - accuracy: 0.6081 - val_loss: 0.7221 - val_accuracy: 0.5490
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6410 - accuracy: 0.6069 - val_loss: 0.7336 - val_accuracy: 0.5319
# 20/20 [==============================] - 0s 11ms/step - loss: 0.
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4178 - accuracy: 0.7754 - val_loss: 1.1859 - val_accuracy: 0.5925
# 20/20 [==============================] - 0s 13ms/step - loss: 0.4186 - accuracy: 0.7774 - val_loss: 1.1704 - val_accuracy: 0.5895
# 20/20 [==============================] - 0s 11ms/step - loss: 0.4125 - accuracy: 0.7819 - val_loss: 1.1194 - val_accuracy: 0.5925
# 20/20 [==============================] - 0s 13ms/step - loss: 0.4140 - accuracy: 0.7766 - val_loss: 1.1111 - val_accuracy: 0.5925
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4079 - accuracy: 0.7809 - val_loss: 1.1278 - val_accuracy: 0.5854
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4083 - accuracy: 0.7832 - val_loss: 1.1449 - val_accuracy: 0.5854
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4076 - accuracy: 0.7883 - val_loss: 1.1428 - val_accuracy: 0.5865
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4095 - accuracy: 0.7802 - val_loss: 1.1481 - val_accuracy: 0.5885
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4108 - accuracy: 0.7860 - val_loss: 1.2199 - val_accuracy: 0.6016
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4063 - accuracy: 0.7771 - val_loss: 1.2458 - val_accuracy: 0.5905
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4044 - accuracy: 0.7837 - val_loss: 1.1996 - val_accuracy: 0.5915
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4066 - accuracy: 0.7822 - val_loss: 1.1866 - val_accuracy: 0.5844
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3989 - accuracy: 0.7890 - val_loss: 1.2590 - val_accuracy: 0.5865
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3946 - accuracy: 0.7943 - val_loss: 1.2301 - val_accuracy: 0.5844
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3925 - accuracy: 0.7964 - val_loss: 1.1946 - val_accuracy: 0.5945
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3930 - accuracy: 0.7908 - val_loss: 1.2498 - val_accuracy: 0.6097
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3885 - accuracy: 0.7948 - val_loss: 1.2986 - val_accuracy: 0.5976
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3827 - accuracy: 0.7948 - val_loss: 1.2154 - val_accuracy: 0.6016
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3733 - accuracy: 0.8045 - val_loss: 1.1851 - val_accuracy: 0.6107
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3681 - accuracy: 0.8080 - val_loss: 1.2020 - val_accuracy: 0.6168
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3646 - accuracy: 0.8052 - val_loss: 1.2086 - val_accuracy: 0.6218
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3646 - accuracy: 0.8070 - val_loss: 1.2097 - val_accuracy: 0.6127
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3731 - accuracy: 0.8004 - val_loss: 1.2243 - val_accuracy: 0.5865
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3768 - accuracy: 0.7986 - val_loss: 1.2318 - val_accuracy: 0.5915
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3806 - accuracy: 0.7961 - val_loss: 1.2864 - val_accuracy: 0.5854
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3794 - accuracy: 0.8012 - val_loss: 1.3127 - val_accuracy: 0.5945
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3816 - accuracy: 0.7989 - val_loss: 1.2149 - val_accuracy: 0.6057
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3727 - accuracy: 0.8103 - val_loss: 1.2375 - val_accuracy: 0.6026
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3774 - accuracy: 0.8024 - val_loss: 1.2463 - val_accuracy: 0.6047
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3715 - accuracy: 0.8052 - val_loss: 1.2678 - val_accuracy: 0.5945
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3663 - accuracy: 0.8118 - val_loss: 1.2289 - val_accuracy: 0.6087
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3569 - accuracy: 0.8158 - val_loss: 1.1829 - val_accuracy: 0.6127
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3551 - accuracy: 0.8146 - val_loss: 1.2150 - val_accuracy: 0.6077
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3538 - accuracy: 0.8163 - val_loss: 1.2354 - val_accuracy: 0.5935
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3541 - accuracy: 0.8125 - val_loss: 1.2310 - val_accuracy: 0.6036
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3603 - accuracy: 0.8095 - val_loss: 1.2410 - val_accuracy: 0.5945
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3683 - accuracy: 0.8057 - val_loss: 1.3108 - val_accuracy: 0.6006
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3572 - accuracy: 0.8103 - val_loss: 1.2468 - val_accuracy: 0.6107
# 20/20 [==============================] - 0s 11ms/step - loss: 0.
- val_accuracy: 0.6047
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3199 - accuracy: 0.8368 - val_loss: 1.5334 - val_accuracy: 0.5986
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3277 - accuracy: 0.8287 - val_loss: 1.5282 - val_accuracy: 0.6026
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3374 - accuracy: 0.8244 - val_loss: 1.5150 - val_accuracy: 0.6047
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3244 - accuracy: 0.8333 - val_loss: 1.4575 - val_accuracy: 0.6138
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3189 - accuracy: 0.8343 - val_loss: 1.3710 - val_accuracy: 0.6107
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3144 - accuracy: 0.8376 - val_loss: 1.3869 - val_accuracy: 0.6107
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3093 - accuracy: 0.8462 - val_loss: 1.4047 - val_accuracy: 0.6117
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3001 - accuracy: 0.8421 - val_loss: 1.4805 - val_accuracy: 0.6067
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2904 - accuracy: 0.8447 - val_loss: 1.4864 - val_accuracy: 0.6077
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2901 - accuracy: 0.8467 - val_loss: 1.5380 - val_accuracy: 0.6168
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2929 - accuracy: 0.8416 - val_loss: 1.5030 - val_accuracy: 0.6158
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2964 - accuracy: 0.8457 - val_loss: 1.4899 - val_accuracy: 0.6117
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3000 - accuracy: 0.8432 - val_loss: 1.4488 - val_accuracy: 0.6138
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2940 - accuracy: 0.8482 - val_loss: 1.4830 - val_accuracy: 0.6097
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2906 - accuracy: 0.8482 - val_loss: 1.4396 - val_accuracy: 0.6168
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2941 - accuracy: 0.8472 - val_loss: 1.3959 - val_accuracy: 0.6178
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2956 - accuracy: 0.8452 - val_loss: 1.4849 - val_accuracy: 0.6168
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2973 - accuracy: 0.8457 - val_loss: 1.5253 - val_accuracy: 0.6208
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2949 - accuracy: 0.8475 - val_loss: 1.5614 - val_accuracy: 0.6158
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2958 - accuracy: 0.8424 - val_loss: 1.5643 - val_accuracy: 0.6107
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2979 - accuracy: 0.8439 - val_loss: 1.4887 - val_accuracy: 0.6158
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2996 - accuracy: 0.8424 - val_loss: 1.5307 - val_accuracy: 0.6208
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2951 - accuracy: 0.8454 - val_loss: 1.5338 - val_accuracy: 0.6198
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2971 - accuracy: 0.8485 - val_loss: 1.4771 - val_accuracy: 0.6117
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2971 - accuracy: 0.8480 - val_loss: 1.4910 - val_accuracy: 0.6087
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2993 - accuracy: 0.8490 - val_loss: 1.5289 - val_accuracy: 0.6198
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2908 - accuracy: 0.8464 - val_loss: 1.5441 - val_accuracy: 0.6087
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3010 - accuracy: 0.8424 - val_loss: 1.5145 - val_accuracy: 0.6178
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3085 - accuracy: 0.8437 - val_loss: 1.6077 - val_accuracy: 0.6138
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2942 - accuracy: 0.8472 - val_loss: 1.5785 - val_accuracy: 0.6077
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3046 - accuracy: 0.8419 - val_loss: 1.4807 - val_accuracy: 0.6178
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3071 - accuracy: 0.8421 - val_loss: 1.4570 - val_accuracy: 0.6077
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3042 - accuracy: 0.8401 - val_loss: 1.5179 - val_accuracy: 0.6047
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3116 - accuracy: 0.8391 - val_loss: 1.5198 - val_accuracy: 0.6026
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3149 - accuracy: 0.8406 - val_loss: 1.5240 - val_accuracy: 0.5956
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3145 - accuracy: 0.8396 - val_loss: 1.5894 - val_accuracy: 0.5986
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3065 - accuracy: 0.8452 - val_loss: 1.5404 - val_accuracy: 0.6259
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3093 - accuracy: 0.8427 - val_loss: 1.4875 - val_accuracy: 0.6117
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2989 - accuracy: 0.8459 - val_loss: 1.5443 - val_accuracy: 0.6138
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2960 - accuracy: 0.8485 - val_loss: 1.6493 - val_accuracy: 0.5794
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3010 - accuracy: 0.8444 - val_loss: 1.6295 - val_accuracy: 0.6087
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2975 - accuracy: 0.8447 - val_loss: 1.5221 - val_accuracy: 0.6036
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3054 - accuracy: 0.8454 - val_loss: 1.5736 - val_accuracy: 0.6087
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3168 - accuracy: 0.8376 - val_loss: 1.4716 - val_accuracy: 0.5986
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3198 - accuracy: 0.8358 - val_loss: 1.4218 - val_accuracy: 0.5986
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3246 - accuracy: 0.8338 - val_loss: 1.4474 - val_accuracy: 0.5895
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3222 - accuracy: 0.8363 - val_loss: 1.5062 - val_accuracy: 0.6077
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3006 - accuracy: 0.8459 - val_loss: 1.4786 - val_accuracy: 0.6229
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2852 - accuracy: 0.8553 - val_loss: 1.4937 - val_accuracy: 0.6229
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2739 - accuracy: 0.8558 - val_loss: 1.5054 - val_accuracy: 0.6047
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2664 - accuracy: 0.8596 - val_loss: 1.5356 - val_accuracy: 0.6127
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2666 - accuracy: 0.8609 - val_loss: 1.5385 - val_accuracy: 0.6067
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2680 - accuracy: 0.8631 - val_loss: 1.5077 - val_accuracy: 0.6036
# 20/20 [==============================] - 0s 14ms/step - loss: 0.2647 - accuracy: 0.8626 - val_loss: 1.5786 - val_accuracy: 0.6117
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2587 - accuracy: 0.8669 - val_loss: 1.5975 - val_accuracy: 0.6178
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2516 - accuracy: 0.8728 - val_loss: 1.6501 - val_accuracy: 0.6269
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2548 - accuracy: 0.8624 - val_loss: 1.6049 - val_accuracy: 0.6198
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2599 - accuracy: 0.8593 - val_loss: 1.6271 - val_accuracy: 0.6107
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2596 - accuracy: 0.8588 - val_loss: 1.5618 - val_accuracy: 0.6229
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2554 - accuracy: 0.8631 - val_loss: 1.6046 - val_accuracy: 0.6168
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2547 - accuracy: 0.8682 - val_loss: 1.5793 - val_accuracy: 0.6269
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2567 - accuracy: 0.8662 - val_loss: 1.6440 - val_accuracy: 0.6249
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2515 - accuracy: 0.8692 - val_loss: 1.6058 - val_accuracy: 0.6218
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2474 - accuracy: 0.8679 - val_loss: 1.5991 - val_accuracy: 0.6208
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2461 - accuracy: 0.8685 - val_loss: 1.6331 - val_accuracy: 0.6259
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2462 - accuracy: 0.8685 - val_loss: 1.6701 - val_accuracy: 0.6279
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2491 - accuracy: 0.8677 - val_loss: 1.7177 - val_accuracy: 0.6350
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2581 - accuracy: 0.8652 - val_loss: 1.7508 - val_accuracy: 0.6340
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2670 - accuracy: 0.8556 - val_loss: 1.7034 - val_accuracy: 0.6289
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2724 - accuracy: 0.8568 - val_loss: 1.7044 - val_accuracy: 0.6148
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2747 - accuracy: 0.8578 - val_loss: 1.7167 - val_accuracy: 0.6127
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2876 - accuracy: 0.8513 - val_loss: 1.5983 - val_accuracy: 0.5824
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2930 - accuracy: 0.8533 - val_loss: 1.5164 - val_accuracy: 0.6057
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2760 - accuracy: 0.8568 - val_loss: 1.6340 - val_accuracy: 0.6016
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2820 - accuracy: 0.8538 - val_loss: 1.5374 - val_accuracy: 0.6087
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2706 - accuracy: 0.8614 - val_loss: 1.5478 - val_accuracy: 0.6127
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2643 - accuracy: 0.8634 - val_loss: 1.6058 - val_accuracy: 0.6289
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2595 - accuracy: 0.8606 - val_loss: 1.6614 - val_accuracy: 0.6299

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.figure(num=None, figsize=(16, 8), dpi=90, facecolor='w', edgecolor='k')
plt.plot()
plt.plot(train_acc)
plt.plot(val_acc)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
y_predict = np.round(model.predict(X_test_norm)) 
y_predict = np.array([i[0] for i in y_predict.tolist()])
print("Test accuracy : "+str(sum(y_predict == y_test)/len(y_test)*100))
# Out:
# Test accuracy : 65.21035598705501

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
target_names = ['negative', 'positive']
C = confusion_matrix(y_test,y_predict) 
C = C / C.astype(np.float).sum(axis=1)*100
sns.heatmap(C, annot=True, fmt=".2f",cmap="GnBu",xticklabels=target_names, yticklabels=target_names)
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.show()
